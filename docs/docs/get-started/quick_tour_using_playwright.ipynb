# %% [markdown]
# <div id="colab_button\">
#     <h1>LaVague: Quick-tour guide</h1>
#     <a target="_blank\" href="https://colab.research.google.com/github/lavague-ai/lavague/blob/main/docs/docs/get-started/quick-tour.ipynb">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#     </div>

# %% [markdown]
# ## Introduction
#
# LaVague is an open-source framework allowing users to leverage AI to turn natural language instructions into executable code to automate UI actions, such as filling in a form, etc.
#
# In this quick tour, we are going to show you how you can quickly get started with LaVague to:
# - Launch an interactive Gradio where you can test running example actions on a webpage
# - Generate the Python code needed to perform an action on the webpage of your choice based on natural language instructions
#
# > Pre-requisites: Note, if you are running the notebook locally, you will need Python (tested on python>=3.8) and pip installed.

# %% [markdown]
# ## Installation

# %% [markdown]
# #### Installing Playwright
#
# By default, LaVague now generates code that leverages Playwright to perform user interface actions. Playwright is a modern and powerful library for web automation that provides a high-level API for interacting with web browsers.

# %% [markdown]
# First, we need to install the Playwright Python package:

# %%
# !pip install playwright
# Out:
# Collecting playwright
#   Downloading playwright-1.42.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: greenlet==3.0.3 in /opt/conda/lib/python3.10/site-packages (from playwright) (3.0.3)
# Collecting pyee==11.0.1 (from playwright)
#   Downloading pyee-11.0.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from pyee==11.0.1->playwright) (4.9.0)
# Downloading playwright-1.42.0-py3-none-manylinux1_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 5.4 MB/s eta 0:00:0000:0100:01m
# Downloading pyee-11.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.42.0 pyee-11.0.1

# %% [markdown]
# Next, we need to install the browser binaries. Playwright supports launching Chromium, Firefox, and WebKit browsers. For this example, we'll install the Chromium browser binary:

# %%
# !playwright install chromium
# Out:
# Downloading Chromium 123.0.6312.4 (playwright build v1105) from https://playwright.azureedge.net/builds/chromium/1105/chromium-linux.zip
# 154.7 MiB [                    ] 0% 0.0s154.7 MiB [                    ] 0% 45.0s154.7 MiB [                    ] 0% 37.1s154.7 MiB [                    ] 0% 22.6s154.7 MiB [                    ] 0% 15.6s154.7 MiB [                    ] 0% 10.4s154.7 MiB [                    ] 1% 8.7s154.7 MiB [                    ] 1% 6.8s154.7 MiB [=                   ] 2% 5.7s154.7 MiB [=                   ] 3% 5.2s154.7 MiB [=                   ] 4% 4.2s154.7 MiB [=                   ] 5% 3.3s154.7 MiB [=                   ] 7% 3.0s154.7 MiB [==                  ] 8% 2.7s154.7 MiB [==                  ] 9% 2.6s154.7 MiB [==                  ] 9% 2.5s154.7 MiB [==                  ] 11% 2.4s154.7 MiB [==                  ] 11% 2.3s154.7 MiB [===                 ] 12% 2.2s154.7 MiB [===                 ] 13% 2.1s154.7 MiB [===                 ] 14% 2.0s154.7 MiB [===                 ] 15% 2.0s154.7 MiB [===                 ] 16% 2.0s154.7 MiB [====                ] 18% 1.8s154.7 MiB [====                ] 19% 1.7s154.7 MiB [====                ] 20% 1.6s154.7 MiB [====                ] 22% 1.6s154.7 MiB [=====               ] 23% 1.5s154.7 MiB [=====               ] 25% 1.5s154.7 MiB [=====               ] 26% 1.4s154.7 MiB [======              ] 28% 1.3s154.7 MiB [======              ] 29% 1.2s154.7 MiB [======              ] 31% 1.2s154.7 MiB [=======             ] 32% 1.2s154.7 MiB [=======             ] 34% 1.1s154.7 MiB [=======             ] 35% 1.1s154.7 MiB [=======             ] 37% 1.0s154.7 MiB [========            ] 38% 1.0s154.7 MiB [========            ] 40% 0.9s154.7 MiB [=========           ] 42% 0.9s154.7 MiB [=========           ] 44% 0.8s154.7 MiB [=========           ] 45% 0.8s154.7 MiB [==========          ] 48% 0.8s154.7 MiB [==========          ] 49% 0.7s154.7 MiB [==========          ] 51% 0.7s154.7 MiB [===========         ] 53% 0.7s154.7 MiB [===========         ] 55% 0.6s154.7 MiB [============        ] 57% 0.6s154.7 MiB [============        ] 59% 0.6s154.7 MiB [============        ] 60% 0.5s154.7 MiB [=============       ] 62% 0.5s154.7 MiB [=============       ] 64% 0.5s154.7 MiB [=============       ] 66% 0.4s154.7 MiB [==============      ] 68% 0.4s154.7 MiB [==============      ] 70% 0.4s154.7 MiB [==============      ] 71% 0.4s154.7 MiB [===============     ] 73% 0.3s154.7 MiB [===============     ] 75% 0.3s154.7 MiB [===============     ] 77% 0.3s154.7 MiB [================    ] 79% 0.3s154.7 MiB [================    ] 80% 0.2s154.7 MiB [=================   ] 82% 0.2s154.7 MiB [=================   ] 84% 0.2s154.7 MiB [=================   ] 86% 0.2s154.7 MiB [==================  ] 87% 0.1s154.7 MiB [==================  ] 89% 0.1s154.7 MiB [==================  ] 91% 0.1s154.7 MiB [=================== ] 93% 0.1s154.7 MiB [=================== ] 94% 0.1s154.7 MiB [=================== ] 96% 0.0s154.7 MiB [====================] 98% 0.0s154.7 MiB [====================] 99% 0.0s154.7 MiB [====================] 100% 0.0s
# Chromium 123.0.6312.4 (playwright build v1105) downloaded to /root/.cache/ms-playwright/chromium-1105
# Downloading FFMPEG playwright build v1009 from https://playwright.azureedge.net/builds/ffmpeg/1009/ffmpeg-linux.zip
# 2.6 MiB [                    ] 0% 0.0s2.6 MiB [                    ] 2% 0.7s2.6 MiB [=                   ] 5% 0.7s2.6 MiB [===                 ] 14% 0.4s2.6 MiB [======              ] 28% 0.2s2.6 MiB [===========         ] 54% 0.1s2.6 MiB [================    ] 82% 0.0s2.6 MiB [====================] 100% 0.0s
# FFMPEG playwright build v1009 downloaded to /root/.cache/ms-playwright/ffmpeg-1009
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Please install them with the following command:      ║
# ║                                                      ║
# ║     playwright install-deps                          ║
# ║                                                      ║
# ║ Alternatively, use apt:                              ║
# ║     apt-get install libgbm1                          ║
# ║                                                      ║
# ║ <3 Playwright Team                                   ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/opt/conda/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async Registry._validateHostRequirements (/opt/conda/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/index.js:627:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/opt/conda/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/index.js:725:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/opt/conda/lib/python3.10/site-packages/playwright/driver/package/lib/server/registry/index.js:714:43)
#     at async t.<anonymous> (/opt/conda/lib/python3.10/site-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %%
# !playwright install-deps
# Out:
# Installing dependencies...
# Get:1 https://packages.cloud.google.com/apt gcsfuse-focal InRelease [1225 B]
# Get:2 https://packages.cloud.google.com/apt cloud-sdk InRelease [6361 B]
# Get:3 https://packages.cloud.google.com/apt google-fast-socket InRelease [5015 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Get:5 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 https://packages.cloud.google.com/apt gcsfuse-focal/main amd64 Packages [20.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:9 https://packages.cloud.google.com/apt cloud-sdk/main amd64 Packages [621 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1463 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Get:12 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3424 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3967 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1194 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3492 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [29.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [32.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1489 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3574 kB]
# Fetched 19.5 MB in 3s (7154 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libfontconfig1' instead of 'libfontconfig'
# fonts-liberation is already the newest version (1:1.07.4-11).
# fonts-liberation set to manually installed.
# libatk1.0-0 is already the newest version (2.35.1-1ubuntu2).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.36.0-2).
# libatspi2.0-0 set to manually installed.
# libcairo-gobject2 is already the newest version (1.16.0-4ubuntu1).
# libcairo-gobject2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-4ubuntu1).
# libcairo2 set to manually installed.
# libepoxy0 is already the newest version (1.5.4-1).
# libepoxy0 set to manually installed.
# libevent-2.1-7 is already the newest version (2.1.11-stable-1).
# libevent-2.1-7 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-2ubuntu3).
# libnspr4 is already the newest version (2:4.25-1).
# libnspr4 set to manually installed.
# libopus0 is already the newest version (1.3.1-0ubuntu1).
# libopus0 set to manually installed.
# libpango-1.0-0 is already the newest version (1.44.7-2ubuntu4).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.44.7-2ubuntu4).
# libpangocairo-1.0-0 set to manually installed.
# libpangoft2-1.0-0 is already the newest version (1.44.7-2ubuntu4).
# libpangoft2-1.0-0 set to manually installed.
# libpng16-16 is already the newest version (1.6.37-2).
# libpng16-16 set to manually installed.
# libxcb-shm0 is already the newest version (1.14-2).
# libxcb-shm0 set to manually installed.
# libxcb1 is already the newest version (1.14-2).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1).
# libxcomposite1 set to manually installed.
# libxcursor1 is already the newest version (1:1.2.0-2).
# libxcursor1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-0ubuntu1).
# libxfixes3 is already the newest version (1:5.0.3-2).
# libxfixes3 set to manually installed.
# libxi6 is already the newest version (2:1.7.10-0ubuntu1).
# libxi6 set to manually installed.
# libxkbcommon0 is already the newest version (0.10.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-0ubuntu1).
# libxrandr2 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1).
# libxshmfence1 is already the newest version (1.3-1).
# libxshmfence1 set to manually installed.
# libxt6 is already the newest version (1:1.1.5-1).
# libxt6 set to manually installed.
# libxtst6 is already the newest version (2:1.2.3-1).
# libxtst6 set to manually installed.
# libflite1 is already the newest version (2.1-release-3).
# libflite1 set to manually installed.
# libx264-155 is already the newest version (2:0.155.2917+git0a84d98-2).
# libx264-155 set to manually installed.
# libasound2 is already the newest version (1.2.2-2.1ubuntu2.5).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.34.2-0ubuntu2~20.04.1).
# libatk-bridge2.0-0 set to manually installed.
# libatomic1 is already the newest version (10.5.0-1ubuntu1~20.04).
# libatomic1 set to manually installed.
# libcups2 is already the newest version (2.3.1-9ubuntu1.6).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.16-2ubuntu2.3).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.107-8ubuntu1~20.04.2).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.10.1-2ubuntu0.3).
# libfreetype6 set to manually installed.
# libgdk-pixbuf2.0-0 is already the newest version (2.40.0+dfsg-3ubuntu0.4).
# libgdk-pixbuf2.0-0 set to manually installed.
# libgl1 is already the newest version (1.3.2-1~ubuntu0.20.04.2).
# libgl1 set to manually installed.
# libglib2.0-0 is already the newest version (2.64.6-1~ubuntu20.04.6).
# libgtk-3-0 is already the newest version (3.24.20-0ubuntu1.1).
# libgtk-3-0 set to manually installed.
# libharfbuzz-icu0 is already the newest version (2.6.4-1ubuntu4.2).
# libharfbuzz-icu0 set to manually installed.
# libharfbuzz0b is already the newest version (2.6.4-1ubuntu4.2).
# libharfbuzz0b set to manually installed.
# libicu66 is already the newest version (66.1-2ubuntu2.1).
# libicu66 set to manually installed.
# libjpeg-turbo8 is already the newest version (2.0.3-0ubuntu1.20.04.3).
# libjpeg-turbo8 set to manually installed.
# libnghttp2-14 is already the newest version (1.40.0-1ubuntu0.2).
# libnghttp2-14 set to manually installed.
# libnss3 is already the newest version (2:3.49.1-1ubuntu1.9).
# libnss3 set to manually installed.
# libopenjp2-7 is already the newest version (2.3.1-1ubuntu4.20.04.1).
# libopenjp2-7 set to manually installed.
# libvpx6 is already the newest version (1.8.2-1ubuntu0.2).
# libvpx6 set to manually installed.
# libwayland-client0 is already the newest version (1.18.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libwayland-egl1 is already the newest version (1.18.0-1ubuntu0.1).
# libwayland-egl1 set to manually installed.
# libwebp6 is already the newest version (0.6.1-2ubuntu0.20.04.3).
# libwebp6 set to manually installed.
# libx11-6 is already the newest version (2:1.6.9-2ubuntu1.6).
# libx11-6 set to manually installed.
# libx11-xcb1 is already the newest version (2:1.6.9-2ubuntu1.6).
# libx11-xcb1 set to manually installed.
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# xvfb is already the newest version (2:1.20.13-1ubuntu1~20.04.15).
# The following additional packages will be installed:
#   fonts-ubuntu libaspell15 libegl-mesa0 libsecret-common
# Suggested packages:
#   aspell libenchant-2-voikko libenchant-voikko
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma aspell-en | aspell-dictionary
#   | aspell6a-dictionary enchant-2 enchant gnome-shell | notification-daemon
# The following NEW packages will be installed:
#   fonts-ipafont-gothic fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-ubuntu
#   fonts-wqy-zenhei libaspell15 libdbus-glib-1-2 libegl-mesa0 libegl1
#   libenchant-2-2 libenchant1c2a libevdev2 libgbm1 libgles2 libgudev-1.0-0
#   libhyphen0 libnotify4 libopengl0 libsecret-1-0 libsecret-common
#   libwayland-server0 libwebpdemux2 libwoff1 libxslt1.1 ttf-ubuntu-font-family
#   ttf-unifont xfonts-cyrillic xfonts-scalable
# The following packages will be upgraded:
#   libxml2
# 1 upgraded, 28 newly installed, 0 to remove and 53 not upgraded.
# Need to get 28.1 MB of archives.
# After this operation, 69.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-ipafont-gothic all 00303-18ubuntu1 [3526 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-wqy-zenhei all 0.9.45-7ubuntu1 [7468 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libxml2 amd64 2.9.10+dfsg-5ubuntu0.20.04.7 [640 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-color-emoji all 0~20200916-1~ubuntu20.04.1 [9940 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-tlwg-loma-otf all 1:0.7.1-3 [98.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-ubuntu all 0.83-4ubuntu1 [1458 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaspell15 amd64 0.60.8-1ubuntu0.1 [328 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libdbus-glib-1-2 amd64 0.110-5fakssync1 [59.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-server0 amd64 1.18.0-1ubuntu0.1 [31.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgbm1 amd64 21.2.6-0ubuntu0.1~20.04.2 [29.2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl-mesa0 amd64 21.2.6-0ubuntu0.1~20.04.2 [96.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libenchant-2-2 amd64 2.2.8-1ubuntu0.20.04.1 [45.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/universe amd64 libenchant1c2a amd64 1.6.0-11.3build1 [64.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libgudev-1.0-0 amd64 1:233-1 [14.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libhyphen0 amd64 2.8.8-7 [27.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnotify4 amd64 0.7.9-1ubuntu3.20.04.2 [19.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-common all 0.20.4-0ubuntu1 [3940 B]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-1-0 amd64 0.20.4-0ubuntu1 [110 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebpdemux2 amd64 0.6.1-2ubuntu0.20.04.3 [9560 B]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libwoff1 amd64 1.0.2-1build2 [42.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libxslt1.1 amd64 1.1.34-4ubuntu0.20.04.1 [151 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/universe amd64 ttf-ubuntu-font-family all 1:0.83-4ubuntu1 [10.2 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 ttf-unifont all 1:12.0.01-2 [3137 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/universe amd64 xfonts-cyrillic all 1:1.0.4 [387 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-scalable all 1:1.0.3-1.1 [304 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl1 amd64 1.3.2-1~ubuntu0.20.04.2 [31.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libevdev2 amd64 1.9.0+dfsg-1ubuntu0.2 [31.6 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles2 amd64 1.3.2-1~ubuntu0.20.04.2 [15.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopengl0 amd64 1.3.2-1~ubuntu0.20.04.2 [29.2 kB]
# Fetched 28.1 MB in 1s (33.2 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 113807 files and directories currently installed.)
# Preparing to unpack .../00-fonts-ipafont-gothic_00303-18ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-18ubuntu1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../01-fonts-wqy-zenhei_0.9.45-7ubuntu1_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-7ubuntu1) ...
# Preparing to unpack .../02-libxml2_2.9.10+dfsg-5ubuntu0.20.04.7_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.10+dfsg-5ubuntu0.20.04.7) over (2.9.10+dfsg-5ubuntu0.20.04.6) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../03-fonts-noto-color-emoji_0~20200916-1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (0~20200916-1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../04-fonts-tlwg-loma-otf_1%3a0.7.1-3_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.1-3) ...
# Selecting previously unselected package fonts-ubuntu.
# Preparing to unpack .../05-fonts-ubuntu_0.83-4ubuntu1_all.deb ...
# Unpacking fonts-ubuntu (0.83-4ubuntu1) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../06-libaspell15_0.60.8-1ubuntu0.1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-1ubuntu0.1) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../07-libdbus-glib-1-2_0.110-5fakssync1_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.110-5fakssync1) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../08-libwayland-server0_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../09-libgbm1_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgbm1:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libegl-mesa0:amd64.
# Preparing to unpack .../10-libegl-mesa0_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../11-libenchant-2-2_2.2.8-1ubuntu0.20.04.1_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Selecting previously unselected package libenchant1c2a:amd64.
# Preparing to unpack .../12-libenchant1c2a_1.6.0-11.3build1_amd64.deb ...
# Unpacking libenchant1c2a:amd64 (1.6.0-11.3build1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../13-libgudev-1.0-0_1%3a233-1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:233-1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../14-libhyphen0_2.8.8-7_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../15-libnotify4_0.7.9-1ubuntu3.20.04.2_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.9-1ubuntu3.20.04.2) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../16-libsecret-common_0.20.4-0ubuntu1_all.deb ...
# Unpacking libsecret-common (0.20.4-0ubuntu1) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../17-libsecret-1-0_0.20.4-0ubuntu1_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Selecting previously unselected package libwebpdemux2:amd64.
# Preparing to unpack .../18-libwebpdemux2_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebpdemux2:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../19-libwoff1_1.0.2-1build2_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build2) ...
# Selecting previously unselected package libxslt1.1:amd64.
# Preparing to unpack .../20-libxslt1.1_1.1.34-4ubuntu0.20.04.1_amd64.deb ...
# Unpacking libxslt1.1:amd64 (1.1.34-4ubuntu0.20.04.1) ...
# Selecting previously unselected package ttf-ubuntu-font-family.
# Preparing to unpack .../21-ttf-ubuntu-font-family_1%3a0.83-4ubuntu1_all.deb ...
# Unpacking ttf-ubuntu-font-family (1:0.83-4ubuntu1) ...
# Selecting previously unselected package ttf-unifont.
# Preparing to unpack .../22-ttf-unifont_1%3a12.0.01-2_all.deb ...
# Unpacking ttf-unifont (1:12.0.01-2) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../23-xfonts-cyrillic_1%3a1.0.4_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.4) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../24-xfonts-scalable_1%3a1.0.3-1.1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.1) ...
# Selecting previously unselected package libegl1:amd64.
# Preparing to unpack .../25-libegl1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libegl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../26-libevdev2_1.9.0+dfsg-1ubuntu0.2_amd64.deb ...
# Unpacking libevdev2:amd64 (1.9.0+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package libgles2:amd64.
# Preparing to unpack .../27-libgles2_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles2:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libopengl0:amd64.
# Preparing to unpack .../28-libopengl0_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libopengl0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libwayland-server0:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up libwoff1:amd64 (1.0.2-1build2) ...
# Setting up libhyphen0:amd64 (2.8.8-7) ...
# Setting up libgbm1:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up fonts-noto-color-emoji (0~20200916-1~ubuntu20.04.1) ...
# Setting up libaspell15:amd64 (0.60.8-1ubuntu0.1) ...
# Setting up ttf-unifont (1:12.0.01-2) ...
# Setting up fonts-ubuntu (0.83-4ubuntu1) ...
# Setting up libwebpdemux2:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Setting up fonts-wqy-zenhei (0.9.45-7ubuntu1) ...
# Setting up libenchant1c2a:amd64 (1.6.0-11.3build1) ...
# Setting up libopengl0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libegl-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libgles2:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.1-3) ...
# Setting up libdbus-glib-1-2:amd64 (0.110-5fakssync1) ...
# Setting up libnotify4:amd64 (0.7.9-1ubuntu3.20.04.2) ...
# Setting up fonts-ipafont-gothic (00303-18ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up xfonts-cyrillic (1:1.0.4) ...
# Setting up libegl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up ttf-ubuntu-font-family (1:0.83-4ubuntu1) ...
# Setting up libevdev2:amd64 (1.9.0+dfsg-1ubuntu0.2) ...
# Setting up libxml2:amd64 (2.9.10+dfsg-5ubuntu0.20.04.7) ...
# Setting up libgudev-1.0-0:amd64 (1:233-1) ...
# Setting up libsecret-common (0.20.4-0ubuntu1) ...
# Setting up xfonts-scalable (1:1.0.3-1.1) ...
# Setting up libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Setting up libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Setting up libxslt1.1:amd64 (1.1.34-4ubuntu0.20.04.1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.14) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...

# %% [markdown]
# >Note: If you encounter any issues with the installation, please refer to the Playwright documentation for more detailed instructions and troubleshooting steps.

# %% [markdown]
# With Playwright installed, we are now ready to generate and execute code using the LaVague framework.

# %% [markdown]
# ### Installing LaVague
#
# We now need to install LaVague, which contains the `ActionEngine` module dedicated to handling all the key AI operations and the `CommandCenter` module, which orchestrates the whole workflow, as well as the `LaVague CLI` tool.
#
# > Note, here we will install LaVague from the latest GitHub commit on `main` to be sure we have the very latest files at this early fast-moving stage of the project. However, we do provide a PyPi package and will move to installing the package via pip once the project is more stable.

# %%
# !git clone https://github.com/ImadZaoug/LaVague.git
# !pip install -e LaVague
# Out:
# Cloning into 'LaVague'...
# remote: Enumerating objects: 735, done.
# remote: Counting objects: 100% (268/268), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 735 (delta 219), reused 147 (delta 131), pack-reused 467
# Receiving objects: 100% (735/735), 20.43 MiB | 31.65 MiB/s, done.
# Resolving deltas: 100% (379/379), done.
# Obtaining file:///kaggle/working/LaVague
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting llama-index==0.10.19 (from lavague==1.0.4.post1)
#   Downloading llama_index-0.10.19-py3-none-any.whl.metadata (8.8 kB)
# Collecting llama-index-agent-openai==0.1.5 (from lavague==1.0.4.post1)
#   Downloading llama_index_agent_openai-0.1.5-py3-none-any.whl.metadata (695 bytes)
# Collecting llama-index-cli==0.1.9 (from lavague==1.0.4.post1)
#   Downloading llama_index_cli-0.1.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core==0.10.19 (from lavague==1.0.4.post1)
#   Downloading llama_index_core-0.10.19-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-embeddings-azure-openai==0.1.5 (from lavague==1.0.4.post1)
#   Downloading llama_index_embeddings_azure_openai-0.1.5-py3-none-any.whl.metadata (796 bytes)
# Collecting llama-index-embeddings-huggingface==0.1.4 (from lavague==1.0.4.post1)
#   Downloading llama_index_embeddings_huggingface-0.1.4-py3-none-any.whl.metadata (806 bytes)
# Collecting llama-index-embeddings-openai==0.1.6 (from lavague==1.0.4.post1)
#   Downloading llama_index_embeddings_openai-0.1.6-py3-none-any.whl.metadata (654 bytes)
# Collecting llama-index-indices-managed-llama-cloud==0.1.4 (from lavague==1.0.4.post1)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy==0.9.48 (from lavague==1.0.4.post1)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-azure-openai==0.1.5 (from lavague==1.0.4.post1)
#   Downloading llama_index_llms_azure_openai-0.1.5-py3-none-any.whl.metadata (786 bytes)
# Collecting llama-index-llms-huggingface==0.1.4 (from lavague==1.0.4.post1)
#   Downloading llama_index_llms_huggingface-0.1.4-py3-none-any.whl.metadata (741 bytes)
# Collecting llama-index-llms-openai==0.1.9 (from lavague==1.0.4.post1)
#   Downloading llama_index_llms_openai-0.1.9-py3-none-any.whl.metadata (558 bytes)
# Collecting llama-index-multi-modal-llms-openai==0.1.4 (from lavague==1.0.4.post1)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai==0.1.4 (from lavague==1.0.4.post1)
#   Downloading llama_index_program_openai-0.1.4-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai==0.1.3 (from lavague==1.0.4.post1)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file==0.1.9 (from lavague==1.0.4.post1)
#   Downloading llama_index_readers_file-0.1.9-py3-none-any.whl.metadata (969 bytes)
# Collecting llama-index-readers-llama-parse==0.1.3 (from lavague==1.0.4.post1)
#   Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-retrievers-bm25==0.1.3 (from lavague==1.0.4.post1)
#   Downloading llama_index_retrievers_bm25-0.1.3-py3-none-any.whl.metadata (700 bytes)
# Collecting tree-sitter==0.21.0 (from lavague==1.0.4.post1)
#   Downloading tree_sitter-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Collecting tree-sitter-languages==1.10.2 (from lavague==1.0.4.post1)
#   Downloading tree_sitter_languages-1.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting nest-asyncio==1.6.0 (from lavague==1.0.4.post1)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting selenium==4.18.1 (from lavague==1.0.4.post1)
#   Downloading selenium-4.18.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting google-search-results==2.4.2 (from lavague==1.0.4.post1)
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dotenv==1.0.1 (from lavague==1.0.4.post1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting accelerate==0.28.0 (from lavague==1.0.4.post1)
#   Downloading accelerate-0.28.0-py3-none-any.whl.metadata (18 kB)
# Collecting bitsandbytes==0.42.0 (from lavague==1.0.4.post1)
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting gradio==4.21.0 (from lavague==1.0.4.post1)
#   Downloading gradio-4.21.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (2.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate==0.28.0->lavague==1.0.4.post1) (0.4.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes==0.42.0->lavague==1.0.4.post1) (1.11.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from google-search-results==2.4.2->lavague==1.0.4.post1) (2.31.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (5.2.0)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (0.108.0)
# Collecting ffmpy (from gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.12.0 (from gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading gradio_client-0.12.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (0.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (3.7.5)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (3.9.10)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (9.5.0)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (2.5.3)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ruff>=0.2.2 (from gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading ruff-0.3.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting semantic-version~=2.0 (from gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (4.9.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from gradio==4.21.0->lavague==1.0.4.post1) (0.25.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.19->lavague==1.0.4.post1) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (3.9.1)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core==0.10.19->lavague==1.0.4.post1)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (2024.2.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core==0.10.19->lavague==1.0.4.post1)
#   Downloading llamaindex_py_client-0.1.13-py3-none-any.whl.metadata (762 bytes)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (3.2.1)
# Collecting nltk<4.0.0,>=3.8.1 (from llama-index-core==0.10.19->lavague==1.0.4.post1)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting openai>=1.1.0 (from llama-index-core==0.10.19->lavague==1.0.4.post1)
#   Downloading openai-1.14.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (8.2.3)
# Collecting tiktoken>=0.3.3 (from llama-index-core==0.10.19->lavague==1.0.4.post1)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (4.66.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core==0.10.19->lavague==1.0.4.post1) (0.9.0)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-embeddings-huggingface==0.1.4->lavague==1.0.4.post1) (4.38.1)
# Collecting azure-identity<2.0.0,>=1.15.0 (from llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1)
#   Downloading azure_identity-1.15.0-py3-none-any.whl.metadata (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file==0.1.9->lavague==1.0.4.post1)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file==0.1.9->lavague==1.0.4.post1)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file==0.1.9->lavague==1.0.4.post1)
#   Downloading PyMuPDF-1.24.0-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file==0.1.9->lavague==1.0.4.post1) (4.0.2)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file==0.1.9->lavague==1.0.4.post1)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse==0.1.3->lavague==1.0.4.post1)
#   Downloading llama_parse-0.3.9-py3-none-any.whl.metadata (3.4 kB)
# Collecting rank-bm25<0.3.0,>=0.2.2 (from llama-index-retrievers-bm25==0.1.3->lavague==1.0.4.post1)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium==4.18.1->lavague==1.0.4.post1) (1.26.18)
# Collecting trio~=0.17 (from selenium==4.18.1->lavague==1.0.4.post1)
#   Downloading trio-0.25.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting trio-websocket~=0.9 (from selenium==4.18.1->lavague==1.0.4.post1)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/conda/lib/python3.10/site-packages (from selenium==4.18.1->lavague==1.0.4.post1) (2024.2.2)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.12.0->gradio==4.21.0->lavague==1.0.4.post1)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague==1.0.4.post1) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague==1.0.4.post1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague==1.0.4.post1) (4.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio==4.21.0->lavague==1.0.4.post1) (4.20.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio==4.21.0->lavague==1.0.4.post1) (0.12.1)
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1)
#   Downloading azure_core-1.30.1-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1) (41.0.7)
# Collecting msal<2.0.0,>=1.24.0 (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1)
#   Downloading msal-1.28.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions<2.0.0,>=0.3.0 (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1)
#   Downloading msal_extensions-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file==0.1.9->lavague==1.0.4.post1) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated>=1.2.9.3->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.14.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==4.21.0->lavague==1.0.4.post1) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==4.21.0->lavague==1.0.4.post1) (1.0.4)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==4.21.0->lavague==1.0.4.post1) (3.6)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==4.21.0->lavague==1.0.4.post1) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.21.0->lavague==1.0.4.post1) (0.14.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate==0.28.0->lavague==1.0.4.post1) (3.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.21.0->lavague==1.0.4.post1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.21.0->lavague==1.0.4.post1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.21.0->lavague==1.0.4.post1) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.21.0->lavague==1.0.4.post1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.21.0->lavague==1.0.4.post1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.21.0->lavague==1.0.4.post1) (2.8.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.19->lavague==1.0.4.post1) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.19->lavague==1.0.4.post1) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.21.0->lavague==1.0.4.post1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.21.0->lavague==1.0.4.post1) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.21.0->lavague==1.0.4.post1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.21.0->lavague==1.0.4.post1) (2.14.6)
# Collecting PyMuPDFb==1.24.0 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file==0.1.9->lavague==1.0.4.post1)
#   Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->google-search-results==2.4.2->lavague==1.0.4.post1) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.19->lavague==1.0.4.post1) (3.0.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.28.0->lavague==1.0.4.post1) (1.12)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.37.0->llama-index-embeddings-huggingface==0.1.4->lavague==1.0.4.post1) (0.15.2)
# Requirement already satisfied: sortedcontainers in /opt/conda/lib/python3.10/site-packages (from trio~=0.17->selenium==4.18.1->lavague==1.0.4.post1) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium==4.18.1->lavague==1.0.4.post1)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from trio~=0.17->selenium==4.18.1->lavague==1.0.4.post1) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium==4.18.1->lavague==1.0.4.post1)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (13.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.19->lavague==1.0.4.post1) (1.0.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium==4.18.1->lavague==1.0.4.post1) (1.7.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->llama-index-core==0.10.19->lavague==1.0.4.post1) (3.20.2)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->gradio==4.21.0->lavague==1.0.4.post1) (0.32.0.post1)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.21.0->lavague==1.0.4.post1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.21.0->lavague==1.0.4.post1) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.21.0->lavague==1.0.4.post1) (0.16.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2.0.0,>=1.24.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1) (2.8.0)
# Collecting portalocker<3,>=1.0 (from msal-extensions<2.0.0,>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (2.17.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate==0.28.0->lavague==1.0.4.post1) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague==1.0.4.post1) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.21.0->lavague==1.0.4.post1) (0.1.2)
# Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 14.0 MB/s eta 0:00:0000:010:01m
# Downloading gradio-4.21.0-py3-none-any.whl (17.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 53.1 MB/s eta 0:00:0000:0100:01
# Downloading llama_index-0.10.19-py3-none-any.whl (5.6 kB)
# Downloading llama_index_agent_openai-0.1.5-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.9-py3-none-any.whl (25 kB)
# Downloading llama_index_core-0.10.19-py3-none-any.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 70.0 MB/s eta 0:00:00:00:0100:01
# Downloading llama_index_embeddings_azure_openai-0.1.5-py3-none-any.whl (3.0 kB)
# Downloading llama_index_embeddings_huggingface-0.1.4-py3-none-any.whl (7.7 kB)
# Downloading llama_index_embeddings_openai-0.1.6-py3-none-any.whl (6.0 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.4-py3-none-any.whl (6.6 kB)
# Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 54.0 MB/s eta 0:00:00:00:01
# Downloading llama_index_llms_azure_openai-0.1.5-py3-none-any.whl (4.5 kB)
# Downloading llama_index_llms_huggingface-0.1.4-py3-none-any.whl (7.2 kB)
# Downloading llama_index_llms_openai-0.1.9-py3-none-any.whl (10.0 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Downloading llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.9-py3-none-any.whl (35 kB)
# Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Downloading llama_index_retrievers_bm25-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 79.5 MB/s eta 0:00:00:00:010:01
# Downloading tree_sitter-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (496 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.6/496.6 kB 24.1 MB/s eta 0:00:00
# Downloading tree_sitter_languages-1.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 74.5 MB/s eta 0:00:00:00:0100:01
# Downloading gradio_client-0.12.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 16.1 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading azure_identity-1.15.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/164.7 kB 10.1 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 8.8 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_parse-0.3.9-py3-none-any.whl (6.8 kB)
# Downloading llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 5.6 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 50.0 MB/s eta 0:00:00
# Downloading openai-1.14.2-py3-none-any.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 16.7 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.0-cp310-none-manylinux2014_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 73.7 MB/s eta 0:00:00:00:01
# Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 38.4 MB/s eta 0:00:0000:0100:01
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading ruff-0.3.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 51.2 MB/s eta 0:00:0000:0100:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 45.1 MB/s eta 0:00:0000:01
# Downloading trio-0.25.0-py3-none-any.whl (467 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 3.0 MB/s eta 0:00:0000:0100:01m
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 11.8 MB/s eta 0:00:00
# Downloading msal-1.28.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 6.2 MB/s eta 0:00:00
# Downloading msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 8.0 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: lavague, google-search-results, ffmpy
#   Building editable for lavague (pyproject.toml) ... done
#   Created wheel for lavague: filename=lavague-1.0.4.post1-0.editable-py3-none-any.whl size=12517 sha256=249b24b6406bfc33cc47cb1258f114a0af0333eab99640d58b3ddf308c252fdb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n8v4r8ps/wheels/fa/33/0f/66852a4503e182917ec468ca5ebec46653bd0104d6537ba1d3
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32010 sha256=7586842d23cc83f2da16ffc139a8212c557decd0b2f1361aa2ca5aa6f200ed46
#   Stored in directory: /root/.cache/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=a4a0ec1cbf8adebb178b14e041b838cae6566931c0fae79f0df1ba265b47c313
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built lavague google-search-results ffmpy

# %% [markdown]
# ## Running LaVague with OpenAI's GPT3.5
#
# ### OpenAI API set up
#
# Depending on the LLM we want to use, we need to set certain environment variables required for LaVague to work.
#
# ⚠️ For this demo, we will use LaVague with GPT3.5 via the OpenAI API, so we will need to set our OpenAI key below for this example to work.
#
# > If you don't have an OpenAI API key, you can see the OpenAI website for details [on how to create one](https://openai.com/product). Note, that this is a paid service - for a free alternative, see our [HuggingFace API integration](../integrations/hugging-face-api.ipynb)

# %%
import os

#os.environ['OPENAI_API_KEY'] = "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"

# %% [markdown]
# ### Gemini API set up
# You can uncommente the section with gemini.py to use gemeni as an LLM

# %%
#os.environ['GOOGLE_API_KEY'] = "AIzaSyDE2osAYDuqBrX8p82HRUY9TXieQkl4qoo"

# %% [markdown]
# ### HuggingFace API set up
# "You can uncomment the section in 'huggingface_inference.py' to use NousResearch/Nous-Hermes-2-Mixtral-8x7B-DPO as an LLM. You can personalize the LLM as you wish by changing the configurations in 'huggingface_inference.py'."

# %%
os.environ['HF_TOKEN'] = "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"

# %% [markdown]
# ### LaVague Launch
#
# LaVague has two CLI commands `launch` and `build` - let's start by taking a look at the `launch` command which will launch an interactive Gradio where you can perform actions on your desired website.
#
# The command we will use to do this is:
# `lavague-launch --file_path hf.txt --config_path openai.py`
#
# - We provide the `file_path` option with a text file containing the URL of the website we want to perform an action on and the natural language instructions for the action(s) we wish to perform.
# -  We provide the `config_path` option with a Python file which configures LaVague for the specific LLM or set-up we wish to use.
#
# We provide default configuration files for key integrations.
#
# Let's now download the default config files for OpenAI.

# %%
# !wget https://raw.githubusercontent.com/ImadZaoug/LaVague/main/examples/api/openai.py
# !wget https://raw.githubusercontent.com/ImadZaoug/LaVague/main/examples/api/gemini.py
# !wget https://raw.githubusercontent.com/ImadZaoug/LaVague/main/examples/api/huggingface_inference.py
# !wget https://raw.githubusercontent.com/ImadZaoug/LaVague/main/tests/hf.txt
# Out:
# --2024-03-25 00:18:51--  https://raw.githubusercontent.com/ImadZaoug/LaVague/main/examples/api/openai.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 396 [text/plain]
# Saving to: 'openai.py.1'
#
# openai.py.1         100%[===================>]     396  --.-KB/s    in 0s
#
# 2024-03-25 00:18:51 (22.7 MB/s) - 'openai.py.1' saved [396/396]
#
# --2024-03-25 00:18:52--  https://raw.githubusercontent.com/ImadZaoug/LaVague/main/examples/api/gemini.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 396 [text/plain]
# Saving to: 'gemini.py.1'
#
# gemini.py.1         100%[===================>]     396  --.-KB/s    in 0s
#
# 2024-03-25 00:18:52 (15.6 MB/s) - 'gemini.py.1' saved [396/396]
#
# --2024-03-25 00:18:53--  https://raw.githubusercontent.com/ImadZaoug/LaVague/main/examples/api/huggingface_inference.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1194 (1.2K) [text/plain]
# Saving to: 'huggingface_inference.py.1'
#
# huggingface_inferen 100%[===================>]   1.17K  --.-KB/s    in 0s
#
# 2024-03-25 00:18:53 (52.2 MB/s) - 'huggingface_inference.py.1' saved [1194/1194]
#
# --2024-03-25 00:18:54--  https://raw.githubusercontent.com/ImadZaoug/LaVague/main/tests/hf.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188 [text/plain]
# Saving to: 'hf.txt.1'
#
# hf.txt.1            100%[===================>]     188  --.-KB/s    in 0s
#
# 2024-03-25 00:18:54 (3.34 MB/s) - 'hf.txt.1' saved [188/188]

# %% [markdown]
# We can inspect the `openai.py` configuration file to see the default values we use by default here.
#
# > To learn how these configuration files work and how you can customize them, see our [Customization guide](./customization.md)!
#
# <img src="https://raw.githubusercontent.com/lavague-ai/LaVague/main/docs/assets/openai_py.png"/>
#
# We can now launch our interactive Gradio which will be created with three default instructions which can be executed on the HuggingFace website as defined in the `hf.txt` file.

# %%
#!lavague-launch --file_path hf.txt --config_path openai.py
# !lavague-launch --file_path hf.txt --config_path huggingface_inference.py
#!lavague-launch --file_path hf.txt --config_path gemini.py #It still raises a problem related to Llama_index's dependencies.
# Out:
# config.json: 100%|█████████████████████████████| 743/743 [00:00<00:00, 3.09MB/s]
# model.safetensors: 100%|██████████████████████| 133M/133M [00:00<00:00, 186MB/s]
# tokenizer_config.json: 100%|███████████████████| 366/366 [00:00<00:00, 1.61MB/s]
# vocab.txt: 100%|█████████████████████████████| 232k/232k [00:00<00:00, 5.60MB/s]
# tokenizer.json: 100%|████████████████████████| 711k/711k [00:00<00:00, 4.12MB/s]
# special_tokens_map.json: 100%|██████████████████| 125/125 [00:00<00:00, 567kB/s]
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://5b1166f1caa5eb4496.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)

# %% [markdown]
# You can now click on the public (if you are using Google Colab) or local URL to open the Gradio in your browser.
#
# ⚠️ Note, you will need to interact with the generated Gradio demo to perform the desired automated action.
#
# First, you should click in the URL textbox and press enter.
#
# <img src="https://raw.githubusercontent.com/lavague-ai/LaVague/main/docs/assets/launch_1_openai_py.png" />
#
# Then, you should select your chosen default natural language instruction or write your own, and again click within the instruction textbox and press enter.
#
# At this point, Selenium code in Python is generated by the LLM, which is then executed to perform the desired action on the website.
#
# <img src="https://raw.githubusercontent.com/lavague-ai/LaVague/main/docs/assets/launch_2_openai_py.png" />
#
#
# The action will then be visibly executed in the visual interface, but you can also check out the code LaVague generated and executed to perform this action on the right-hand side of the page.

# %% [markdown]
# ### LaVague Build
#
# We can alternatively use the `lavague-build` command to generate a Python script with the Selenium code needed to perform the desired action.

# %%
#!lavague-build --file_path hf.txt --config_path openai.py
# !lavague-build --file_path hf.txt --config_path huggingface_inference.py
#!lavague-build --file_path hf.txt --config_path gemini.py #It still raises a problem related to Llama_index's dependencies.

# %% [markdown]
# This creates a script in your current directory named `hf_openai.py` - a combination of the two input file names separated by a `_` character.
#
# This script contains the Python code using Selenium generated by the LLM to perform the desired action on the URL as specified in your `hf.txt` configuration file.
#
# We can now inspect the code and execute it locally!
#
# <img src="https://raw.githubusercontent.com/lavague-ai/LaVague/main/docs/assets/build_openai_py.png"/>

# %% [markdown]
# ## Conclusions
#
# That brings us to the end of this quick-tour.
#
# If you have any further questions, join us on the LaVague Discord [here](https://discord.com/invite/SDxn9KpqX9).
